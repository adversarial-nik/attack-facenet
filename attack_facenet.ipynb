# %%
! git clone https://github.com/adversarial-nik/attack-facenet
# Out:
# Cloning into 'attack-facenet'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 26 (delta 0), reused 23 (delta 0), pack-reused 0
# Unpacking objects: 100% (26/26), done.
# Checking out files: 100% (16/16), done.

# %%
# %cd attack-facenet/
# Out:
# /content/attack-facenet

# %%
# !python attack.py
# Out:
# [INFO] loading pre-trained facenet model...
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/layers/normalization/batch_normalization.py:520: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# (1, 160, 160, 3) <class 'numpy.ndarray'>
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
#  [+] cost: 1.4417484
#  [+] cost: 1.115543
#  [+] cost: 0.92563915
#  [+] cost: 0.77727664
#  [+] cost: 0.65804422
#  [+] cost: 0.54667014
#  [+] cost: 0.46938729
# ...

# %%
from IPython.display import Image, display
display(Image('hacked_image.png'))
print()
display(Image('images/mark.jpg'))

# %%
# !python validate_attack.py
# Out:
# 2021-09-23 16:02:35.567747: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-09-23 16:02:35.567796: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (eba053b8f14a): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 2021-09-23 16:02:40.692225: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# distance of target with input image:  13.584689140319824
# distance of target with hacked image:  6.5422892570495605
